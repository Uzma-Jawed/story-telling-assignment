# %% [markdown]
# **Uzma Jawed**
#
# ### 🏠 Housing Prices Dataset Analysis
# Exploratory Data Analysis (EDA), statistics, and visualizations using `pandas`, `seaborn`, and `matplotlib`.

# %% [markdown]
# Dataset: Use the Kaggle dataset “Housing Price Prediction”, which includes house details such as price, area, number of bedrooms, furnished status, and proximity to main roads.

# %% [markdown]
# Dataset Link : https://www.kaggle.com/datasets/yasserh/housing-prices-dataset

# %% [markdown]
# Part 1: Setup & Load Data
#
# Download the CSV from Kaggle.
#
# Load it into pandas:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_data = pd.read_csv("Housing.csv")

# %% [markdown]
# Part 2: Explore & Clean Data
#
# Use df.head() and df.describe() to get an overview.
#
# Check and handle any missing values.

# %%
# Display the dataset
house_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# Describe the dataset
house_data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
house_data.describe(include='all')
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  545.000000  545.000000  545.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std     1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %%
house_data.describe(include=[object])
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
house_data.value_counts()
# Out:
# price     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1750000   2910  3         1          1        no        no         no        no               no               0        no        furnished           1
#           3620  2         1          1        yes       no         no        no               no               0        no        unfurnished         1
#           3850  3         1          2        yes       no         no        no               no               0        no        unfurnished         1
# 1767150   2400  3         1          1        no        no         no        no               no               0        no        semi-furnished      1
# 1820000   3000  2         1          1        yes       no         yes       no               no               2        no        unfurnished         1
# ...

# %%
# Use value_counts() on a specific column
house_data['airconditioning'].value_counts()
# Out:
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64

# %%
house_data['furnishingstatus'].unique()  # This returns the unique values in that column
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
house_data['furnishingstatus'].nunique()  # Returns number of unique values
# Out:
# 3

# %%
house_data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# Part 3: Compute Statistics
#
# For numerical columns like:
#
# Price | Area | Bedrooms
#
# Compute the following using pandas:
#
# mean() | median() | mode() | var() | std() | skew() | kurt()| min(), max()

# %%
numerical_cols = ['price', 'area', 'bedrooms']

# %%
print("Mean:\n", house_data[numerical_cols].mean())
# Out:
# Mean:
#  price       4.766729e+06
# area        5.150541e+03
# bedrooms    2.965138e+00
# dtype: float64

# %%
print("\nMedian:\n", house_data[numerical_cols].median())
# Out:
# Median:
#  price       4340000.0
# area           4600.0
# bedrooms          3.0
# dtype: float64

# %%
print("\nMode:\n", house_data[numerical_cols].mode().iloc[0])
# Out:
# Mode:
#  price       3500000.0
# area           6000.0
# bedrooms          3.0
# Name: 0, dtype: float64

# %%
print("\nVariance:\n", house_data[numerical_cols].var())
# Out:
# Variance:
#  price       3.498544e+12
# area        4.709512e+06
# bedrooms    5.447383e-01
# dtype: float64

# %%
print("\nStandard Deviation:\n", house_data[numerical_cols].std())
# Out:
# Standard Deviation:
#  price       1.870440e+06
# area        2.170141e+03
# bedrooms    7.380639e-01
# dtype: float64

# %%
print("\nSkewness:\n", house_data[numerical_cols].skew())
# Out:
# Skewness:
#  price       1.212239
# area        1.321188
# bedrooms    0.495684
# dtype: float64

# %%
print("\nKurtosis:\n", house_data[numerical_cols].kurt())
# Out:
# Kurtosis:
#  price       1.960130
# area        2.751480
# bedrooms    0.728323
# dtype: float64

# %%
print("\nMinimum:\n", house_data[numerical_cols].min())
# Out:
# Minimum:
#  price       1750000
# area           1650
# bedrooms          1
# dtype: int64

# %%
print("\nMaximum:\n", house_data[numerical_cols].max())
# Out:
# Maximum:
#  price       13300000
# area           16200
# bedrooms           6
# dtype: int64

# %%
# Covariance matrix
covariance_matrix = house_data.cov(numeric_only=True)
print(covariance_matrix)
# Out:
#                   price          area       bedrooms      bathrooms  \
# price      3.498544e+12  2.175676e+09  505946.425931  486409.333378
# area       2.175676e+09  4.709512e+06     243.232140     211.346617
# bedrooms   5.059464e+05  2.432321e+02       0.544738       0.138674
# bathrooms  4.864093e+05  2.113466e+02       0.138674       0.252476
# stories    6.826446e+05  1.581294e+02       0.261589       0.142171
# parking    6.194673e+05  6.599897e+02       0.088562       0.076842
#
#                  stories        parking
# price      682644.632825  619467.324204
# area          158.129368     659.989696
# bedrooms        0.261589       0.088562
# bathrooms       0.142171       0.076842
# stories         0.752543       0.034043
# parking         0.034043       0.742330

# %%
# Correlation matrix
correlation_matrix = house_data.corr(numeric_only=True)
print(correlation_matrix)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
# 📌 Visualizing Correlation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# 📌 GroupBy and Aggregation

# Average house value for each age group
house_data.groupby("price")['area'].mean().head()
# Out:
# price
# 1750000    3460.0
# 1767150    2400.0
# 1820000    3000.0
# 1855000    2990.0
# 1890000    2674.5
# Name: area, dtype: float64

# %%
house_data.groupby("price")['area'].mean()
# Out:
# price
# 1750000     3460.0
# 1767150     2400.0
# 1820000     3000.0
# 1855000     2990.0
# 1890000     2674.5
#              ...
# 10850000    7500.0
# 11410000    7420.0
# 12215000    7500.0
# 12250000    9460.0
# 13300000    7420.0
# Name: area, Length: 219, dtype: float64

# %%
# Group by 'bedrooms' and calculate mean of all numeric columns
house_data.groupby("bedrooms").mean(numeric_only=True).head()
# Out:
#                  price         area  bathrooms   stories   parking
# bedrooms
# 1         2.712500e+06  3710.000000   1.000000  1.000000  0.000000
# 2         3.632022e+06  4636.235294   1.058824  1.169118  0.492647
# 3         4.954598e+06  5226.620000   1.266667  1.933333  0.723333
# 4         5.729758e+06  5582.063158   1.621053  2.305263  0.915789
# 5         5.819800e+06  6291.500000   1.800000  2.000000  0.600000

# %%
house_data.groupby("bedrooms")["price"].mean()
# Out:
# bedrooms
# 1    2.712500e+06
# 2    3.632022e+06
# 3    4.954598e+06
# 4    5.729758e+06
# 5    5.819800e+06
# 6    4.791500e+06
# Name: price, dtype: float64

# %%
# Mean and Median 
house_data.groupby('price')['area'].agg(['mean', 'median']).head()
# Out:
#            mean  median
# price
# 1750000  3460.0  3620.0
# 1767150  2400.0  2400.0
# 1820000  3000.0  3000.0
# 1855000  2990.0  2990.0
# 1890000  2674.5  2674.5

# %%
# Aggregating multiple functions on multiple columns
house_data.aggregate({
    'price': ['mean', 'sum'],
    'area': ['mean', 'max']
})
# Out:
#              price          area
# mean  4.766729e+06   5150.541284
# sum   2.597867e+09           NaN
# max            NaN  16200.000000

# %%
# GroupBy with 3 Columns and Mean
grouped_mean = house_data.groupby(['price', 'area', 'bedrooms'])['stories'].mean()
grouped_mean.head()
# Out:
# price    area  bedrooms
# 1750000  2910  3           1.0
#          3620  2           1.0
#          3850  3           2.0
# 1767150  2400  3           1.0
# 1820000  3000  2           1.0
# Name: stories, dtype: float64

# %%
grouped_stats = house_data.groupby(['price', 'area', 'bedrooms'])['stories'].agg(['mean', 'max', 'min', 'count'])
grouped_stats.head()
# Out:
#                        mean  max  min  count
# price   area bedrooms
# 1750000 2910 3          1.0    1    1      1
#         3620 2          1.0    1    1      1
#         3850 3          2.0    2    2      1
# 1767150 2400 3          1.0    1    1      1
# 1820000 3000 2          1.0    1    1      1

# %%
grouped = house_data.groupby(['bedrooms', 'airconditioning', 'furnishingstatus'])['price'].agg(['mean', 'max', 'min', 'count'])
grouped.head()
# Out:
#                                                    mean      max      min  \
# bedrooms airconditioning furnishingstatus
# 1        no              furnished         3.150000e+06  3150000  3150000
#                          unfurnished       2.275000e+06  2275000  2275000
# 2        no              furnished         4.113375e+06  6930000  2520000
#                          semi-furnished    3.806667e+06  5600000  2275000
#                          unfurnished       2.946562e+06  4865000  1750000
#
#                                            count
# bedrooms airconditioning furnishingstatus
# 1        no              furnished             1
#                          unfurnished           1
# 2        no              furnished            24
#                          semi-furnished       42
#                          unfurnished          48

# %% [markdown]
# Part 4: Optional Visualization
#
# Plot histograms or box plots for Price and Area.
#
# Use scatter plots like Price vs Area if you want to show trends.

# %%
sns.scatterplot(x='area', y='price', data=house_data)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='area', y='price', data=house_data, hue='furnishingstatus', style='airconditioning', palette='Set2', s=70, edgecolor='w', alpha=0.9)

plt.title('House Price vs Area', fontsize=14)
plt.xlabel('Area (sq ft)', fontsize=12)
plt.ylabel('Price (PKR)', fontsize=12)
plt.legend(title='Furnishing / AC', loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='furnishingstatus', y='price', data=house_data)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(x='furnishingstatus', y='price', data=house_data, jitter=True, hue='airconditioning',
              palette='Set2', dodge=True, size=6, alpha=0.7)

plt.title('House Price by Furnishing Status', fontsize=14)
plt.xlabel('Furnishing Status', fontsize=12)
plt.ylabel('Price (PKR)', fontsize=12)
plt.legend(title='Air Conditioning')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
house_data['price'].plot(kind='line')
# Out:
# <Axes: >

# %%
# Sort by price for better trend display
sorted_data = house_data.sort_values('price').reset_index()

plt.figure(figsize=(10, 5))
plt.plot(sorted_data.index, sorted_data['price'], color='royalblue', linewidth=2)

plt.title("Line Plot of House Prices (Sorted)", fontsize=14)
plt.xlabel("House Index (sorted by price)", fontsize=12)
plt.ylabel("Price (PKR)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
furnish_avg = house_data.groupby('furnishingstatus')['price'].mean()

plt.figure(figsize=(8, 4))
furnish_avg.plot(kind='line', marker='o', color='teal')

plt.title("Average House Price by Furnishing Status", fontsize=14)
plt.xlabel("Furnishing Status", fontsize=12)
plt.ylabel("Average Price (PKR)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
house_data['area'].plot()
# Out:
# <Axes: >

# %%
# Optional: sort by area for trend clarity
sorted_df = house_data.sort_values('area').reset_index()

plt.figure(figsize=(10, 5))
plt.plot(sorted_df.index, sorted_df['area'], color='darkorange', linewidth=2)

plt.title("Line Plot of House Area (Sorted by Area)", fontsize=14)
plt.xlabel("House Index (sorted by area)", fontsize=12)
plt.ylabel("Area (sq ft)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# compare average area by furnishing status:
house_data.groupby("furnishingstatus")["area"].mean().plot(kind="bar", color='skyblue')
plt.title("Average Area by Furnishing Status")
plt.ylabel("Average Area (sq ft)")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
house_data['price'].plot(kind='hist', bins=10)
sns.histplot(house_data['price'], kde=True)
sns.kdeplot(house_data['price'])
# Out:
# <Axes: xlabel='price', ylabel='Frequency'>

# %%
plt.figure(figsize=(10, 6))

# 1. Histogram using Pandas
house_data['price'].plot(kind='hist', bins=10, color='lightblue', edgecolor='black', alpha=0.6, label='Histogram')

# 2. Histogram + KDE using Seaborn
sns.histplot(house_data['price'], kde=True, color='skyblue', edgecolor='black', alpha=0.6, label='Seaborn Hist + KDE')

# 3. KDE-only for comparison
sns.kdeplot(house_data['price'], color='darkblue', linewidth=2, label='KDE Curve')

plt.title("Distribution of House Prices", fontsize=14)
plt.xlabel("Price (PKR)", fontsize=12)
plt.ylabel("Frequency / Density", fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
house_data['price'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(house_data['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=house_data, x='price', bins=20, kde=True,
             color='skyblue', edgecolor='black', alpha=0.7)

plt.title("Distribution of House Prices with KDE", fontsize=14)
plt.xlabel("Price (PKR)", fontsize=12)
plt.ylabel("Frequency / Density", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(house_data['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Bar
house_data['airconditioning'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='airconditioning'>

# %%
plt.figure(figsize=(6, 4))
house_data['airconditioning'].value_counts().plot(kind='bar', color=['lightgreen', 'salmon'], edgecolor='black')

plt.title("Air Conditioning Availability in Houses", fontsize=14)
plt.xlabel("Air Conditioning", fontsize=12)
plt.ylabel("Number of Houses", fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Count
sns.countplot(x='furnishingstatus', data=house_data)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
plt.figure(figsize=(7, 5))
sns.countplot(x='furnishingstatus', data=house_data, palette='Set2', edgecolor='black')

plt.title("Count of Houses by Furnishing Status", fontsize=14)
plt.xlabel("Furnishing Status", fontsize=12)
plt.ylabel("Number of Houses", fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\1772485162.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='furnishingstatus', data=house_data, palette='Set2', edgecolor='black')

# %%
# sort the categories by frequecy
order = house_data['furnishingstatus'].value_counts().index
sns.countplot(x='furnishingstatus', data=house_data, order=order, palette='Set2')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\1489052344.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='furnishingstatus', data=house_data, order=order, palette='Set2')
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(x='airconditioning', data=house_data, palette='Set2')
plt.title("Count of Houses by Air Conditioning")
plt.xlabel("Air Conditioning")
plt.ylabel("Count")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\2670086521.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='airconditioning', data=house_data, palette='Set2')

# %%
# Box
sns.boxplot(x='furnishingstatus', y='price', data=house_data)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='furnishingstatus', y='price', data=house_data, palette='pastel', width=0.6, linewidth=2)

plt.title("House Price Distribution by Furnishing Status", fontsize=14)
plt.xlabel("Furnishing Status", fontsize=12)
plt.ylabel("Price (PKR)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\1865470162.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='furnishingstatus', y='price', data=house_data, palette='pastel', width=0.6, linewidth=2)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='furnishingstatus', y='price', data=house_data, palette='pastel')
sns.swarmplot(x='furnishingstatus', y='price', data=house_data, color='black', alpha=0.6)

plt.title("Price Distribution with Data Points by Furnishing Status")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\2369923920.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='furnishingstatus', y='price', data=house_data, palette='pastel')

# %%
# Violin
sns.violinplot(x='furnishingstatus', y='price', data=house_data)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='furnishingstatus', y='price', data=house_data, palette='Set3', inner='box', linewidth=1.2)

plt.title("Violin Plot of House Prices by Furnishing Status", fontsize=14)
plt.xlabel("Furnishing Status", fontsize=12)
plt.ylabel("Price (PKR)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\1552766747.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='furnishingstatus', y='price', data=house_data, palette='Set3', inner='box', linewidth=1.2)

# %%
sns.violinplot(x='furnishingstatus', y='price', hue='airconditioning', data=house_data, palette='Set2', split=True)
plt.title("Price Distribution by Furnishing & Air Conditioning")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(house_data)

# %%
# Optional: select only relevant numeric columns + categorical for hue
pairplot_data = house_data[['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'furnishingstatus']]

sns.pairplot(pairplot_data, hue='furnishingstatus', palette='Set2', diag_kind='kde', height=2.5)
plt.suptitle("Pairwise Relationships in Housing Data", fontsize=16, y=1.02)
plt.show()

# %%
# pie chart for distribution

furnish_counts = house_data['furnishingstatus'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(furnish_counts, labels=furnish_counts.index, autopct='%1.1f%%', colors=['#87CEEB', '#FFDAB9', '#90EE90'], startangle=140)
plt.title("Distribution of Furnishing Status")
plt.axis('equal')  # Makes the pie chart circular
plt.show()

# %%
# airconditionig availability

ac_counts = house_data['airconditioning'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(ac_counts, labels=ac_counts.index, autopct='%1.1f%%', colors=['#FF9999', '#66B2FF'], startangle=90)
plt.title("Air Conditioning Availability")
plt.axis('equal')
plt.show()

# %%
# Donut chart for Furnishing Status
plt.figure(figsize=(6, 6))
plt.pie(furnish_counts, labels=furnish_counts.index, autopct='%1.1f%%', startangle=90, colors=['#E0BBE4','#957DAD','#D291BC'], wedgeprops={'width':0.4})
plt.title("Furnishing Status (Donut Chart)")
plt.axis('equal')
plt.show()

# %% [markdown]
#  Part 5: Storytelling
# Write a 5–8 sentence story describing your findings:
#
# What do average and spread of prices tell?
# Are there any outliers or surprises?
# Does the data show consistency or big differences?
# What insights can someone take from this housing market?
#
#
# 🌟 Sample Story:
# “I studied the price and size of homes from a real estate dataset. The average price was around $250,000, with a wide range from $80,000 to over $500,000. The high standard deviation showed that housing prices are not consistent — likely due to location, size, or condition.
#
# Most houses had 2–4 bedrooms, but I found a few large homes priced lower than expected, possibly due to old construction or location issues. The price distribution was right-skewed, meaning a few expensive homes raised the average. Overall, the data shows a mixed market, where area plays a role but other factors matter too.”
#
# ___
# ___

# %% [markdown]
# 🌟Story (My Finings):
#
# "The housing dataset reveals a market with significant price variation influenced by key features such as area, furnishing status, and air conditioning. While larger and fully furnished homes tend to be more expensive, there are some exceptions where big houses are priced lower — likely due to missing comfort features.
#
# The analysis shows that area has the strongest impact on price, while the number of bedrooms alone doesn’t guarantee a higher value. The presence of outliers and a right-skewed distribution indicates that a few high-priced homes can distort the average.
#
# Overall, this dataset reflects a diverse and non-uniform housing market, where buyers and investors should consider not just size, but also amenities and property condition when evaluating value."
