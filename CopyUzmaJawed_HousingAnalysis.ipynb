# %% [markdown]
# Explore a Housing Prices Dataset Using Pandas
#
# Dataset: Use the Kaggle dataset “Housing Price Prediction”, which includes house details such as price, area, number of bedrooms, furnished status, and proximity to main roads.

# %% [markdown]
# Dataset Link : https://www.kaggle.com/datasets/yasserh/housing-prices-dataset

# %%
# Part 1: Setup & Load Data

import pandas as pd

# Load the dataset
df = pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# 🔍 Part 2: Explore & Clean Data

print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
print(df.describe())
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# Check for missing values

print(df.isnull().sum())
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Drop missing values
df = df.dropna()

# %%
# 📊 Part 3: Compute Statistics

# Select relevant numerical columns
cols = ['price', 'area', 'bedrooms']

# %%
# Compute stats
for col in cols:
    print(f"\nStatistics for {col}:")
    print(f"Mean: {df[col].mean()}")
    print(f"Median: {df[col].median()}")
    print(f"Mode: {df[col].mode()[0]}")
    print(f"Variance: {df[col].var()}")
    print(f"Standard Deviation: {df[col].std()}")
    print(f"Skewness: {df[col].skew()}")
    print(f"Kurtosis: {df[col].kurt()}")
    print(f"Minimum: {df[col].min()}")
    print(f"Maximum: {df[col].max()}")
# Out:
# Statistics for price:
# Mean: 4766729.247706422
# Median: 4340000.0
# Mode: 3500000
# Variance: 3498544355820.573
# Standard Deviation: 1870439.6156573922
# Skewness: 1.2122388370279802
# Kurtosis: 1.9601302314151994
# Minimum: 1750000
# Maximum: 13300000
#
# Statistics for area:
# Mean: 5150.54128440367
# Median: 4600.0
# Mode: 6000
# Variance: 4709512.057575554
# Standard Deviation: 2170.141022508803
# Skewness: 1.321188343153483
# Kurtosis: 2.7514801872608086
# Minimum: 1650
# Maximum: 16200
#
# Statistics for bedrooms:
# Mean: 2.9651376146788992
# Median: 3.0
# Mode: 3
# Variance: 0.544738262277388
# Standard Deviation: 0.7380638605685743
# Skewness: 0.49568394074553473
# Kurtosis: 0.7283228752894284
# Minimum: 1
# Maximum: 6

# %%
# 📈 Part 4: Optional Visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for Price and Area
df['price'].hist(bins=30)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

df['area'].hist(bins=30)
plt.title('Area Distribution')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplots
sns.boxplot(x=df['price'])
plt.title('Boxplot of Price')
plt.show()

sns.boxplot(x=df['area'])
plt.title('Boxplot of Area')
plt.show()

# %%
# Scatter plot
sns.scatterplot(x='area', y='price', data=df)
plt.title('Price vs Area')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ✨ Part 5: Storytelling
#
# *Based on analysis of 545 Bangalore home listings from [Kaggle's Housing Prices Dataset](https://www.kaggle.com/datasets/yasserh/housing-prices-dataset), this report reveals...*
#
# ### **🏡 The Hidden Patterns in India's Housing Market**
#
# After analyzing 545 home listings, I uncovered some surprising truths about what really drives property prices. The numbers tell a fascinating story beyond just "bigger equals more expensive."
#
# #### **The Big Picture**
# - Prices ranged from **₹1.75M for a compact 1BHK** to **₹13.3M for a luxury 4BHK**
# - Average home: **₹4.77M** (median ₹4.34M) – the ₹400k difference hints at high-value outliers
# - Most common price: **₹3.5M** (mode) shows where the market clusters
#
# #### **Key Discoveries**
#
# **1. The Bedroom Paradox**
# - Average bedrooms: **2.97** (median 3)
# - But! The most expensive home wasn't the one with most bedrooms (a **4BHK** topped the list at ₹13.3M, while some 5-6 bedroom homes sold for less)
# - **Why?** The premium homes had:
#   - Prime locations (**prefarea=yes**)
#   - Full furnishings
#   - Luxury features (AC, parking, guest rooms)
#
# **2. Size Matters... But Not How You'd Think**
# - Average area: **5,151 sq.ft** (median 4,600)
# - The **skewness (1.32)** reveals many moderately-sized homes with a few huge outliers
# - Most surprising find: A **16,200 sq.ft. home** sold for just ₹10.15M – **37% less per sq.ft** than a 7,420 sq.ft. home at ₹13.3M
#   - Missing premium features (no AC, unfurnished) made the difference
#
# **3. The Amenity Premium**
# Homes with these features commanded **20-30%** price bumps:
# - **Air conditioning**: Present in all top 10 most expensive homes
# - **Parking spots**: Average 0.69 per home, but 2+ spots added major value
# - **Preferred area**: Homes marked "prefarea" sold for **15% more** on average
#
# #### **The Price Distribution Story**
# The **right skew (1.21)** in prices reveals:
# - Most homes cluster around ₹3-6M
# - A long tail of luxury properties pulls the average up
# - The **standard deviation (₹1.87M!)** shows extreme variability
#
# #### **What Really Drives Value?**
# A winning combination:
# 1. **Strategic size**: 3BHK in 4,500-6,500 sq.ft. range
# 2. **Turnkey condition**: Furnished > semi-furnished > unfurnished
# 3. **Location perks**: Main road access + preferred area
# 4. **Modern comforts**: AC + at least 1 parking spot
#
# **Final Insight**: In this market, a **well-appointed 3BHK** often outsells larger but basic homes. Smart buyers pay for *livability*, not just square footage.
